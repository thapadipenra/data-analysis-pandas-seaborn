# %% [markdown]
# # Mastering Matplotlib!

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Line Plots

# %%
plt.plot()
# Out:
# []

# %%
plt.plot([2,4,6,8])

# %%
plt.plot([2,4,2,6,8,4])

# %%
salaries=[55000,65000,72000,90000,115000,150000]
ages = [20,25,30,32,40,45]
plt.plot(ages, salaries)

# %%
plt.plot(ages, salaries)
plt.show()

# %%
import numpy as np
nums = np.arange(5)

# %%
plt.plot(nums,nums)
plt.plot(nums, nums*nums)
plt.plot(nums, nums**3)

# %%
plt.figure()
plt.plot(nums,nums)
plt.figure()
plt.plot(nums, nums*nums)
plt.plot(nums, nums**3)

# %%
plt.figure()
plt.plot(nums,nums)
plt.figure()
plt.plot(nums, nums*nums)
plt.figure()
plt.plot(nums, nums**3)

# %%
plt.figure(figsize=(2,6))
plt.plot(nums,nums)

# %%
plt.figure(figsize=(6,6))
plt.plot(nums,nums**3)

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('fivethirtyeight')

# %%
plt.plot(nums,nums)
plt.plot(nums, nums*nums)
plt.plot(nums, nums**3)

# %%
plt.style.use('seaborn')

# %%
plt.plot(nums,nums)
plt.plot(nums, nums*nums)
plt.plot(nums, nums**3)

# %%
plt.style.use('ggplot')

# %%
plt.plot(nums, nums)
plt.plot(nums, nums*nums)
plt.plot(nums, nums**3)

# %%
plt.plot(nums, nums, color="olive", linewidth=4)
plt.plot(nums, nums*nums, color="#ff6b6b", linewidth=4)
plt.plot(nums, nums**3, c="#ff9f43", linewidth=4)

# %%
plt.plot(nums, nums, color="olive", linewidth=4, linestyle="dashed")
plt.plot(nums, nums*nums, color="#ff6b6b", linewidth=4, linestyle="dotted")
plt.plot(nums, nums**3, c="#ff9f43", linewidth=4, linestyle="-.")

# %%
plt.plot(nums, nums, color="olive", marker="*", markersize=20, markerfacecolor="#ff9f43")

# %%
salaries=[55000,65000,72000,90000,115000,150000]
ages = [20,25,30,32,40,45]
plt.plot(ages, salaries)
plt.title("Company Salaries")
plt.figure()
plt.plot(nums, nums, color="olive", linewidth=4, linestyle="dashed")
plt.title("Linear Stuff", loc="right")
# Out:
# Text(1.0, 1.0, 'Linear Stuff')

# %%
salaries=[55000,65000,72000,90000,115000,150000]
ages = [20,25,30,32,40,45]
plt.plot(ages, salaries)
plt.title("Company Salaries", fontsize=24, color="olive")
plt.xlabel("Employee Age", labelpad=10)
plt.ylabel("Average Salary", labelpad=10 )
# Out:
# Text(0, 0.5, 'Average Salary')

# %%
plt.figure(figsize=(8,8))
salaries=[55000,65000,72000,90000,115000,150000]
ages = [20,25,30,32,40,45]
plt.plot(ages, salaries)
plt.title("Company Salaries", fontsize=24, color="olive")
plt.xlabel("Employee Age", labelpad=10)
plt.ylabel("Average Salary", labelpad=10 )
plt.xticks([20,25,30,35,40,45])
plt.yticks([60000,80000,100000, 120000, 140000], labels=["60k", "80k", "100k", "120k","140k"])
# Out:
# ([<matplotlib.axis.YTick at 0x7f82a1f9b850>,
# ...
#  [Text(0, 60000, '60k'),
#   Text(0, 80000, '80k'),
#   Text(0, 100000, '100k'),
#   Text(0, 120000, '120k'),
#   Text(0, 140000, '140k')])

# %%
plt.figure(figsize=(8,8))
salaries=[55000,65000,72000,90000,115000,150000]
ages = [20,25,30,32,40,45]
plt.plot(ages, salaries)
plt.xlim(25,40)
plt.ylim(80000, 120000)
# Out:
# (80000.0, 120000.0)

# %%
plt.figure(figsize=(5,5))
plt.plot(nums, color="teal", label="x")
plt.plot(nums**2, color="olive", label="x squared")
plt.plot(nums**3, color="purple",label="x cubed")
plt.legend()

# %%
plt.figure(figsize=(5,5))
plt.plot(nums, color="teal", label="x")
plt.plot(nums**2, color="olive", label="x squared")
plt.plot(nums**3, color="purple",label="x cubed")
plt.legend(loc="center left", shadow=True, frameon=True, facecolor="white")

# %% [markdown]
# ## Bar Plots

# %%
plants = ['Spinach', 'Turnip', 'Rhubarb', 'Broccoli', 'Kale']
died = [10,25,5,30,21]
germinated = [74, 88, 56,69,59]

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, germinated, color="orchid")
plt.title("Germination Rates")
plt.ylabel("Number Of Seeldings")
# Out:
# Text(0, 0.5, 'Number Of Seeldings')

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, died, color="red")
plt.title("Failure Rates")
plt.ylabel("Number Of Dead Seedling")
# Out:
# Text(0, 0.5, 'Number Of Dead Seedling')

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, died, color="#3498db")
plt.bar(plants, germinated, width=0.4, color="#2ecc71", align="edge")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, died, color="#3498db", bottom=germinated )
plt.bar(plants, germinated, color="#2ecc71")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(6,6))
plt.bar(plants, died, color="#3498db", bottom=germinated,label="Failed Seedlings")
plt.bar(plants, germinated, color="#2ecc71", label="Germinated Seedlings")
plt.legend(shadow=True, frameon=True, facecolor="white")
plt.title("Greenhouse Seedlings")
plt.show()

# %%
plt.figure(figsize=(6,6))
plt.barh(plants, germinated, color="#2ecc71")
# Out:
# <BarContainer object of 5 artists>

# %% [markdown]
# ## Histograms

# %%
plt.hist([1,1,2,3,3,3,3,3,4,4,4,5,1,2,1,2,1,2,3,4])
# Out:
# (array([5., 0., 4., 0., 0., 6., 0., 4., 0., 1.]),
#  array([1. , 1.4, 1.8, 2.2, 2.6, 3. , 3.4, 3.8, 4.2, 4.6, 5. ]),
#  <BarContainer object of 10 artists>)

# %%
nums = np.random.randn(100)
plt.hist(nums)
# Out:
# (array([ 2.,  8., 14., 16., 22., 18., 13.,  5.,  1.,  1.]),
#  array([-2.16283575, -1.68679802, -1.21076029, -0.73472256, -0.25868484,
#          0.21735289,  0.69339062,  1.16942835,  1.64546607,  2.1215038 ,
#          2.59754153]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(nums, bins=20, color="olive")
# Out:
# (array([ 1.,  1.,  3.,  5.,  4., 10., 11.,  5., 10., 12., 11.,  7.,  8.,
#          5.,  4.,  1.,  0.,  1.,  0.,  1.]),
#  array([-2.16283575, -1.92481688, -1.68679802, -1.44877915, -1.21076029,
#         -0.97274143, -0.73472256, -0.4967037 , -0.25868484, -0.02066597,
#          0.21735289,  0.45537176,  0.69339062,  0.93140948,  1.16942835,
#          1.40744721,  1.64546607,  1.88348494,  2.1215038 ,  2.35952267,
#          2.59754153]),
#  <BarContainer object of 20 artists>)

# %%
import pandas as pd
titanic = pd.read_csv("data/titanic.csv")
titanic["age"] = pd.to_numeric(titanic["age"], errors="coerce")

# %%
plt.hist(titanic["age"])
# Out:
# (array([ 72.,  62., 274., 250., 161., 108.,  65.,  41.,  10.,   3.]),
#  array([ 0.1667 ,  8.15003, 16.13336, 24.11669, 32.10002, 40.08335,
#         48.06668, 56.05001, 64.03334, 72.01667, 80.     ]),
#  <BarContainer object of 10 artists>)

# %%
first_class = titanic[titanic["pclass"] == 1]["age"]
second_class = titanic[titanic["pclass"] == 2]["age"]
third_class = titanic[titanic["pclass"] == 3]["age"]
plt.hist(first_class, label="1st Class", alpha=0.5, color="#f1c40f", bins=20)
plt.hist(second_class, label="2nd Class", alpha=0.5, color="#3498db", bins=20)
plt.hist(third_class, label="3rd Class", alpha=0.5, color="#e74c3c", bins=20)
plt.legend()
plt.title("Titanic Passenger Ages")
plt.xlabel("Passenger Age")
# Out:
# Text(0.5, 0, 'Passenger Age')

# %% [markdown]
# ## Scatter Plots

# %%
heights = [137,140,142,145,147,150,152,155,157,160]
f_weights = [28.5,30.8,32.6,34.9,36.4,39,40.8,43.1,44.9,47.2]
m_weights = [34.9,38.1,33.5,35.8,46.7, 42.8,43.1,45.8,50.8,58.9]

# %%
plt.scatter(heights, f_weights,  marker="*", label="Female")
plt.scatter(heights, m_weights,marker="d", label="Male")
plt.legend()
plt.xlabel("Height (cm)")
plt.ylabel("Weight (kg)")
# Out:
# Text(0, 0.5, 'Weight (kg)')

# %% [markdown]
# ## Pie Charts

# %%
labels = ["Turkey", "Potatoes", "Pumpkin Pie", "Stuffing"]
prices = [25.99,3.24,9.50, 6.99]

# %%
plt.pie(prices, labels=labels, autopct="%1.1f%%", shadow=True, explode=(0,0,0.1,0))
plt.show()

# %% [markdown]
# ## Subplots

# %%
nums = np.arange(5)
plt.figure(figsize=(10,4))
plt.suptitle("Our First Subplot", fontsize=30)

plt.subplot(1,3,1)
plt.title("X")
plt.plot(nums, nums)

plt.subplot(1,3,2)
plt.plot(nums, nums**2, color="red")
plt.title("X Squared")


plt.subplot(1,3,3)
plt.plot(nums, nums**3, color="yellow")
plt.title("X Cubed")
plt.tight_layout()
plt.show()

# %%
nums = np.arange(5)
plt.figure(figsize=(4,10))
plt.suptitle("Our First Subplot", fontsize=30)

plt.subplot(3,1,1)
plt.title("X")
plt.plot(nums, nums)

plt.subplot(3,1,2)
plt.plot(nums, nums**2, color="red")
plt.title("X Squared")


plt.subplot(3,1,3)
plt.plot(nums, nums**3, color="yellow")
plt.title("X Cubed")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(8,8))
plt.subplot(2,2,1)
plt.plot(nums)

plt.subplot(2,2,2)
plt.plot(nums)


plt.subplot(2,2,3)
plt.plot(nums)


plt.subplot(2,2,4)
plt.plot(nums)

# %%
first_class = titanic[titanic["pclass"] == 1]["age"]
second_class = titanic[titanic["pclass"] == 2]["age"]
third_class = titanic[titanic["pclass"] == 3]["age"]
plt.hist(third_class, label="3rd Class", alpha=0.5, color="#e74c3c", bins=20)
plt.hist(second_class, label="2nd Class", alpha=0.5, color="#3498db", bins=20)
plt.hist(first_class, label="1st Class", alpha=0.5, color="#f1c40f", bins=20)
plt.legend()
plt.title("Titanic Passenger Ages")
plt.xlabel("Passenger Age")
# Out:
# Text(0.5, 0, 'Passenger Age')

# %%
first_class = titanic[titanic["pclass"] == 1]["age"]
second_class = titanic[titanic["pclass"] == 2]["age"]
third_class = titanic[titanic["pclass"] == 3]["age"]

plt.figure(figsize=(10,4))
ax = plt.subplot(1,3,1)
plt.hist(first_class, label="1st Class", color="#f1c40f", bins=20)
plt.title("1st Class")

plt.subplot(1,3,2, sharey=ax)
plt.hist(second_class, label="2nd Class", color="#3498db", bins=20)
plt.title("2nd Class")


plt.subplot(1,3,3, sharey=ax)
plt.hist(third_class, label="3rd Class", color="#e74c3c", bins=20)
plt.title("3rd Class")
# Out:
# Text(0.5, 1.0, '3rd Class')

# %% [markdown]
# ## The Object-Oriented Approach

# %%
fig, axs = plt.subplots(1,2)

# %%
axs[0].hist(first_class)
axs[1].hist(second_class)
axs[0].hist(third_class)
axs[0].set_title("My Title")
axs[0].set_xlabel("Age")
axs[1].set_title("My Other Title")
fig

# %%
fig, axs = plt.subplots(2,2)
axs[0][0].plot(nums,color="red")
axs[0][1].plot(nums*nums)
axs[1][0].plot(nums**3)
axs[1][1].plot(1/nums)

axs[0][1].set_xticks([0,2,4])
# Out:
# /var/folders/kq/2h89lz056cq9kghxk_6k66c40000gn/T/ipykernel_1024/2433834221.py:5: RuntimeWarning: divide by zero encountered in true_divide
#   axs[1][1].plot(1/nums)
# ...

# %%
fig, ax = plt.subplots()
ax.plot(nums)
ax.plot(nums*nums)

# %%
import matplotlib.pyplot as plt

# %%
plt.plot()
plt.show()

# %%
import numpy as np

# %%
a=np.arange(5)

# %%
a
# Out:
# array([0, 1, 2, 3, 4])

# %%
plt.plot(a,a)
plt.plot(a**2)
plt.plot(a,a**3)

# %%
plt.figure()
plt.plot(a,a**2)
plt.show()

# %%
plt.figure()
plt.plot(a,a)
plt.plot(a,a**3)
plt.show()

# %%
plt.figure(figsize=(4,4), dpi=1000), 
plt.plot(a,a)
plt.plot(a,a**3)
plt.show()

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use( 'seaborn')

# %%
plt.figure()
plt.plot(a,a, )
plt.plot(a,a**3)
plt.show()

# %%
plt.plot(a,a, color="#587792",label='line 2')
plt.plot(a, a**2, c="red", marker="*",  mfc="red", ms=20, mec="black", markeredgewidth=2,mfcalt="white",markevery=[0,1,4], label="thapa")
plt.plot(a,a**3, color="olive", linewidth=4, linestyle="dashdot", label="dipen")
plt.show()

# %%
plt.plot(a**2, c="#587792", marker="*",  mfc="red", ms=20, mec="black", markeredgewidth=2,mfcalt="white",markevery=[0,1,4], label="thapa")
plt.title("it's dipen custom")
plt.xlabel("float data point")
plt.ylabel("int data points",)
plt.figure()
plt.plot(a,a, color="#587792",label='line 2')
plt.title("thapa", loc="right", pad=100, )
# plt.xtick([0,1,2,3,4])
# Out:
# Text(1.0, 1.0, 'thapa')

# %%
plt.plot(a,a, color="#587792")
plt.title("thapa", loc="right", pad=100, )
plt.xticks([0,1,4,5], labels=["a","10k","g","5"])
plt.ylim(0,4)
plt.ylim()
# Out:
# (0.0, 4.0)

# %%
x= np.arange(5)
plt.figure(figsize=(8,8))
plt.plot(x, c="olive", label="straight")
plt.plot([60,50,40,20,10], label="random")
plt.plot(x * x, c="teal", label="square")
plt.plot(x**3, c="purple", label="cube")
plt.legend()

# %%
x= np.arange(5)
plt.figure(figsize=(8,8))
plt.plot(x, c="olive", label="straight")
plt.plot(x * x, c="teal", label="square")
plt.plot(x**3, c="purple", label="cube")
plt.legend(loc="upper right", frameon=True, shadow=True, facecolor="white")

# %%
plants = ['Spinach', 'Turnip', 'Rhubarb', 'Broccoli', 'Kale']
died = [10,25,5,30,21]
germinated = [74, 88, 56,69,59]

# %%
plt.figure(figsize=(6,6))
plt.bar(x=plants, height=germinated, color="orchid")
plt.title("germination")
plt.ylabel("germinated")
# Out:
# Text(0, 0.5, 'germinated')

# %%
plt.figure(figsize=(6,6))
plt.bar(x=plants, height=died, color="red")
plt.title("failure")
plt.ylabel("dead")
# Out:
# Text(0, 0.5, 'dead')

# %%
plt.figure(figsize=(6,6))
plt.bar(x=plants, height=germinated, color="orchid", width=0.85)
plt.bar(x=plants, height=died, color="red", bottom=germinated)
plt.title("germination")
plt.ylabel("nothing")
# Out:
# Text(0, 0.5, 'nothing')

# %%
plt.figure(figsize=(6,6))
plt.bar(x=plants, height=died, label="died")
plt.bar(x=plants, height=germinated, width=0.5, align="edge", color="red", label="germinated")
plt.legend()
plt.title("germination")
plt.ylabel("nothing")
# Out:
# Text(0, 0.5, 'nothing')

# %%
plt.figure(figsize=(6,6))
plt.barh(y=plants, width=died, label="died")
plt.barh(y=plants, width=germinated, height=0.5, align="edge", color="red", label="germinated")
plt.legend()
plt.title("germination")
plt.ylabel("nothing")
# Out:
# Text(0, 0.5, 'nothing')

# %%
import numpy as np

# %%
b=np.random.randn(1000)

# %%
plt.hist(b, bins=50)
# Out:
# (array([ 1.,  1.,  1.,  1.,  0.,  0.,  0.,  1.,  2.,  2.,  9.,  6.,  8.,
#         12., 13., 15., 21., 24., 23., 28., 39., 42., 57., 46., 57., 58.,
#         49., 55., 57., 34., 49., 51., 40., 39., 30., 27., 26., 15., 16.,
#         13., 10.,  9.,  3.,  2.,  2.,  1.,  3.,  1.,  0.,  1.]),
#  array([-3.73166035, -3.59314203, -3.45462371, -3.3161054 , -3.17758708,
#         -3.03906876, -2.90055045, -2.76203213, -2.62351381, -2.4849955 ,
#         -2.34647718, -2.20795886, -2.06944055, -1.93092223, -1.79240391,
#         -1.6538856 , -1.51536728, -1.37684896, -1.23833065, -1.09981233,
#         -0.96129401, -0.8227757 , -0.68425738, -0.54573906, -0.40722075,
#         -0.26870243, -0.13018411,  0.0083342 ,  0.14685252,  0.28537084,
#          0.42388915,  0.56240747,  0.70092579,  0.8394441 ,  0.97796242,
#          1.11648074,  1.25499905,  1.39351737,  1.53203569,  1.670554  ,
#          1.80907232,  1.94759063,  2.08610895,  2.22462727,  2.36314558,
# ...

# %%
import pandas as pd

# %%
titanic=pd.read_csv("data/titanic.csv")

# %%
titanic["age"]=pd.to_numeric(titanic["age"], errors="coerce")

# %%
plt.hist(titanic["age"])
# Out:
# (array([ 72.,  62., 274., 250., 161., 108.,  65.,  41.,  10.,   3.]),
#  array([ 0.1667 ,  8.15003, 16.13336, 24.11669, 32.10002, 40.08335,
#         48.06668, 56.05001, 64.03334, 72.01667, 80.     ]),
#  <BarContainer object of 10 artists>)

# %%
first_class=titanic[titanic.pclass==1]["age"]
second_class=titanic[titanic.pclass==2]["age"]
third_class=titanic[titanic.pclass==3]["age"]

# %%
first_class
# Out:
# 0      29.0000
# 1       0.9167
# 2       2.0000
# 3      30.0000
# 4      25.0000
#         ...
# 318        NaN
# 319    31.0000
# 320        NaN
# 321    62.0000
# 322    36.0000
# Name: age, Length: 323, dtype: float64

# %%
plt.hist(first_class,label="first class", alpha=0.5, bins=20)
plt.hist(second_class, label="second class", alpha=0.5, bins=20)
plt.hist(third_class, label="third class", alpha=0.5, bins=20)
plt.legend()

# %%
heights = [137,140,142,145,147,150,152,155,157,160]
f_weights = [28.5,30.8,32.6,34.9,36.4,39,40.8,43.1,44.9,47.2]
m_weights = [34.9,38.1,33.5,35.8,46.7, 42.8,43.1,45.8,50.8,58.9]

# %%
plt.scatter(heights, f_weights, marker="*", label="female weight")
plt.scatter(heights, m_weights, marker="d", label="male weight")
plt.legend()

# %%
labels = ["Turkey", "Potatoes", "Pumpkin Pie", "Stuffing"]
prices = [25.99,3.24,9.50, 6.99]

# %%
plt.pie(prices, labels=labels, explode=(0,0,0,0.1),autopct='%1.2f%%', shadow=True)
plt.show()

# %%
plt.figure(figsize=(10,10), dpi=100)
plt.subplot(2,2,1)
plt.pie(prices, labels=labels, explode=(0,0,0,0.1),autopct='%1.2f%%', shadow=True)
plt.title("pie 2")

plt.subplot(2,2,2)
plt.hist(first_class,label="first class", alpha=0.5, bins=20)
plt.hist(second_class, label="second class", alpha=0.5, bins=20)
plt.hist(third_class, label="third class", alpha=0.5, bins=20)
plt.legend()
plt.title("pie 2")

plt.subplot(2,2,3)
plt.hist(b, bins=50)
plt.title("pie 2")

plt.subplot(2,2,4)
plt.pie(prices, labels=labels, explode=(0,0,0,0.1),autopct='%1.2f%%', shadow=True)
plt.title("pie 2")
plt.suptitle("dipen", fontsize=20)

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10,4))
plt.subplot(1,3,1)
plt.hist(first_class,label="first class", bins=20)
plt.subplot(1,3,2)

plt.hist(second_class, label="second class", bins=20)
plt.subplot(1,3,3)

plt.hist(third_class, label="third class", bins=20)
plt.show()

# %%
plt.figure(figsize=(10,4))
ax=plt.subplot(1,3,1)
plt.hist(first_class,label="first class", bins=20)
plt.subplot(1,3,2, sharey=ax, sharex=ax)

plt.hist(second_class, label="second class", bins=20)
plt.subplot(1,3,3, sharey=ax, sharex=ax)

plt.hist(third_class, label="third class", bins=20)
plt.show()
# sharing axes
