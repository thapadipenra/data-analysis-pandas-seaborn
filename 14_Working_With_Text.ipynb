# %% [markdown]
# # Working With Text Data

# %%
import pandas as pd

# %%
titanic = pd.read_csv("data/titanic.csv")

# %%
titanic['age'] = titanic['age'].replace(['?'], [None]).astype('float')
titanic['fare'] = titanic['fare'].replace(['?'], [None]).astype('float')

# %% [markdown]
# ## Upper( ) and Lower( )

# %%
titanic["name"].str.upper()
# Out:
# 0                         ALLEN, MISS. ELISABETH WALTON
# 1                        ALLISON, MASTER. HUDSON TREVOR
# 2                          ALLISON, MISS. HELEN LORAINE
# 3                  ALLISON, MR. HUDSON JOSHUA CREIGHTON
# 4       ALLISON, MRS. HUDSON J C (BESSIE WALDO DANIELS)
#                              ...
# 1304                               ZABOUR, MISS. HILENI
# 1305                              ZABOUR, MISS. THAMINE
# 1306                          ZAKARIAN, MR. MAPRIEDEDER
# 1307                                ZAKARIAN, MR. ORTIN
# 1308                                 ZIMMERMAN, MR. LEO
# Name: name, Length: 1309, dtype: object

# %%
titanic["name"]
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
titanic["lower_name"] = titanic["name"].str.lower()

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.lower_name.str.capitalize()
# Out:
# 0                         Allen, miss. elisabeth walton
# 1                        Allison, master. hudson trevor
# 2                          Allison, miss. helen loraine
# 3                  Allison, mr. hudson joshua creighton
# 4       Allison, mrs. hudson j c (bessie waldo daniels)
#                              ...
# 1304                               Zabour, miss. hileni
# 1305                              Zabour, miss. thamine
# 1306                          Zakarian, mr. mapriededer
# 1307                                Zakarian, mr. ortin
# 1308                                 Zimmerman, mr. leo
# Name: lower_name, Length: 1309, dtype: object

# %% [markdown]
# ## String Indexing

# %%
titanic["cabin"].str[0]
# Out:
# 0       B
# 1       C
# 2       C
# 3       C
# 4       C
#        ..
# 1304    ?
# 1305    ?
# 1306    ?
# 1307    ?
# 1308    ?
# Name: cabin, Length: 1309, dtype: object

# %%
titanic["deck"] = titanic["cabin"].str[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.groupby("deck").mean()
# Out:
#         pclass  survived        age     sibsp     parch        fare
# deck
# ?     2.617357  0.302761  27.406654  0.503945  0.367850   19.132707
# A     1.000000  0.500000  44.157895  0.181818  0.181818   41.244314
# B     1.000000  0.723077  36.476190  0.446154  0.661538  122.383078
# C     1.000000  0.606383  38.382752  0.680851  0.414894  107.926598
# D     1.130435  0.695652  39.702381  0.413043  0.260870   53.007339
# E     1.243902  0.731707  38.118421  0.341463  0.390244   54.564634
# F     2.380952  0.619048  21.333333  0.428571  0.523810   18.079367
# G     3.000000  0.600000  12.000000  0.600000  1.200000   14.205000
# T     1.000000  0.000000  45.000000  0.000000  0.000000   35.500000

# %%
titanic.groupby("deck")["survived"].mean().sort_values().plot(kind="bar")
# Out:
# <AxesSubplot:xlabel='deck'>

# %% [markdown]
# ## Strip( )

# %%
s = pd.Series(['1. Hawk.  ', '2. Pickle!\n', '3. Melonhead?\t'])

# %%
s
# Out:
# 0         1. Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %%
s.str.strip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
s.str.strip(to_strip="123. \n \t")
# Out:
# 0          Hawk
# 1       Pickle!
# 2    Melonhead?
# dtype: object

# %%
s.str.rstrip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!
# 2    3. Melonhead?
# dtype: object

# %%
s.str.lstrip()
# Out:
# 0         1. Hawk.
# 1       2. Pickle!\n
# 2    3. Melonhead?\t
# dtype: object

# %%
s.str.strip(to_strip="123.")
# Out:
# 0          Hawk.
# 1        Pickle!\n
# 2     Melonhead?\t
# dtype: object

# %% [markdown]
# ## Split( )

# %%
titanic["home.dest"].str.split("/", expand=True)
# Out:
#                   0                  1     2
# 0      St Louis, MO               None  None
# 1     Montreal, PQ    Chesterville, ON  None
# 2     Montreal, PQ    Chesterville, ON  None
# 3     Montreal, PQ    Chesterville, ON  None
# 4     Montreal, PQ    Chesterville, ON  None
# ...             ...                ...   ...
# 1304              ?               None  None
# 1305              ?               None  None
# 1306              ?               None  None
# 1307              ?               None  None
# 1308              ?               None  None
#
# [1309 rows x 3 columns]

# %%
titanic["home"] = titanic["home.dest"].str.split("/", expand=True)[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["destination"] = titanic["home.dest"].str.split("/", expand=True)[1]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["home"].value_counts()
# Out:
# ?                           564
# New York, NY                 64
# Cornwall                     19
# London                       14
# London                       13
#                            ...
# Middleburg Heights, OH        1
# Barre, Co Washington, VT      1
# Oslo, Norway Bayonne, NJ      1
# England Oglesby, IL           1
# ?Havana, Cuba                 1
# Name: home, Length: 339, dtype: int64

# %%
titanic["destination"].value_counts()
# Out:
#  Akron, OH          11
#  Montreal, PQ        9
#  New York, NY        9
#  Detroit, MI         6
#  Cooperstown, NY     5
#                     ..
#  Pennsylvania        1
#  Greenwich CT        1
#  Arlington, NJ       1
#  Toledo, OH          1
#  Birmingham          1
# Name: destination, Length: 77, dtype: int64

# %%
titanic["home.dest"].str.split("/", n=1, expand=True)
# Out:
#                   0                  1
# 0      St Louis, MO               None
# 1     Montreal, PQ    Chesterville, ON
# 2     Montreal, PQ    Chesterville, ON
# 3     Montreal, PQ    Chesterville, ON
# 4     Montreal, PQ    Chesterville, ON
# ...             ...                ...
# 1304              ?               None
# 1305              ?               None
# 1306              ?               None
# 1307              ?               None
# 1308              ?               None
#
# [1309 rows x 2 columns]

# %% [markdown]
# ## Replace( )

# %%
ufos = pd.read_csv("data/nuforc_reports.csv")

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
ufos["duration"]
# Out:
# 0          5 seconds
# 1        3-5 seconds
# 2                NaN
# 3         10 seconds
# 4          2 minutes
#             ...
# 88120      3 minutes
# 88121     20 seconds
# 88122     20 seconds
# 88123      2 minutes
# 88124      3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.replace("seconds", "s")
# Out:
# 0              5 s
# 1            3-5 s
# 2              NaN
# 3             10 s
# 4        2 minutes
#            ...
# 88120    3 minutes
# 88121         20 s
# 88122         20 s
# 88123    2 minutes
# 88124    3 minutes
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.replace("seconds|minutes", "", regex=True)
# Out:
# 0          5
# 1        3-5
# 2         NaN
# 3         10
# 4          2
#          ...
# 88120      3
# 88121     20
# 88122     20
# 88123      2
# 88124      3
# Name: duration, Length: 88125, dtype: object

# %%
def abbrv(reo):
    return reo.group()[0]

# %%
ufos["duration"].str.replace("seconds|minutes|hours", abbrv)
# Out:
# <ipython-input-269-dce69a0bac36>:1: FutureWarning: The default value of regex will change from True to False in a future version.
#   ufos["duration"].str.replace("seconds|minutes|hours", abbrv)
# 0          5 s
# 1        3-5 s
# 2          NaN
# 3         10 s
# 4          2 m
#          ...
# 88120      3 m
# 88121     20 s
# 88122     20 s
# 88123      2 m
# 88124      3 m
# Name: duration, Length: 88125, dtype: object

# %% [markdown]
# ## Contains( )

# %%
ufos["duration"].str.contains("hour")
# Out:
# 0        False
# 1        False
# 2          NaN
# 3        False
# 4        False
#          ...
# 88120    False
# 88121    False
# 88122    False
# 88123    False
# 88124    False
# Name: duration, Length: 88125, dtype: object

# %%
ufos[ufos["duration"].str.contains("day|week|month", na=False)]
# Out:
#                                                  summary  \
# 107    7 large yellow lights with red center  estimat...
# 116    Saw one large ship during the day around noon ...
# 286    film makers in hollywood where talking of film...
# 290                               End of the Century UFO
# 1355   A white ball of light made several appearances...
# ...                                                  ...
# 84021  The Beings and Craft of Taos County.  ((NUFORC...
# 84983  In 1967 I am a little kid now. I am sleeping I...
# 85717  There was a big bright colored triangle object...
# 86210  2 flying diamonds; red and gold lights; creaki...
# 87707  Lights seen from the night sky 1st night-flick...
#
#                           city state            date_time      shape  \
# 107                    Griffin    GA  1984-03-15T20:00:00     circle
# 116                  Knoxville    TN  1986-04-04T23:00:00  rectangle
# 286                    Arizona    AZ  1997-07-07T00:00:00   triangle
# ...

# %%
import pandas as pd

# %%
titanic = pd.read_csv("data/titanic.csv")

# %%
titanic['age'] = titanic['age'].replace(['?'], [None]).astype('float')
titanic['fare'] = titanic['fare'].replace(['?'], [None]).astype('float')

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.name[0]=[1,2,3,4]
# Out:
# /var/folders/kq/2h89lz056cq9kghxk_6k66c40000gn/T/ipykernel_19918/3528372559.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   titanic.name[0]=[1,2,3,4]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                                     [1, 2, 3, 4]
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.name[0].append(6)

# %%
titanic.name[0]
# Out:
# [1, 2, 3, 4, 6]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                                  [1, 2, 3, 4, 6]
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.name.astype("string")[0]
# Out:
# '[1, 2, 3, 4, 6]'

# %%
titanic.name[0]
# Out:
# [1, 2, 3, 4, 6]

# %%
titanic["name"]
# Out:
# 0                         Allen, Miss. Elisabeth Walton
# 1                        Allison, Master. Hudson Trevor
# 2                          Allison, Miss. Helen Loraine
# 3                  Allison, Mr. Hudson Joshua Creighton
# 4       Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#                              ...
# 1304                               Zabour, Miss. Hileni
# 1305                              Zabour, Miss. Thamine
# 1306                          Zakarian, Mr. Mapriededer
# 1307                                Zakarian, Mr. Ortin
# 1308                                 Zimmerman, Mr. Leo
# Name: name, Length: 1309, dtype: object

# %%
# python function
"hello".upper()
# Out:
# 'HELLO'

# %%
"HeLLow".lower()
# Out:
# 'hellow'

# %%
# dont work that way in pandas
titanic["name"].upper() #to work with this method we need to access them under str in pandas.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [33], in <cell line: 2>()
#       1 # dont work that way in pandas
# ----> 2 titanic["name"].upper()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'upper'

# %%
"HeLLow".capitalize()
# Out:
# 'Hellow'

# %%
titanic.name.str.upper()
# Out:
# 0                         ALLEN, MISS. ELISABETH WALTON
# 1                        ALLISON, MASTER. HUDSON TREVOR
# 2                          ALLISON, MISS. HELEN LORAINE
# 3                  ALLISON, MR. HUDSON JOSHUA CREIGHTON
# 4       ALLISON, MRS. HUDSON J C (BESSIE WALDO DANIELS)
#                              ...
# 1304                               ZABOUR, MISS. HILENI
# 1305                              ZABOUR, MISS. THAMINE
# 1306                          ZAKARIAN, MR. MAPRIEDEDER
# 1307                                ZAKARIAN, MR. ORTIN
# 1308                                 ZIMMERMAN, MR. LEO
# Name: name, Length: 1309, dtype: object

# %%
titanic["name"].str.capitalize()
# Out:
# 0                         Allen, miss. elisabeth walton
# 1                        Allison, master. hudson trevor
# 2                          Allison, miss. helen loraine
# 3                  Allison, mr. hudson joshua creighton
# 4       Allison, mrs. hudson j c (bessie waldo daniels)
#                              ...
# 1304                               Zabour, miss. hileni
# 1305                              Zabour, miss. thamine
# 1306                          Zakarian, mr. mapriededer
# 1307                                Zakarian, mr. ortin
# 1308                                 Zimmerman, mr. leo
# Name: name, Length: 1309, dtype: object

# %%
titanic["lower_name"]=titanic.name.str.lower()

# %%
titanic.name.str.
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.cabin.str[0]
# Out:
# 0       B
# 1       C
# 2       C
# 3       C
# 4       C
#        ..
# 1304    ?
# 1305    ?
# 1306    ?
# 1307    ?
# 1308    ?
# Name: cabin, Length: 1309, dtype: object

# %%
titanic["deck"]=titanic["cabin"].str[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic.groupby("deck").mean()
# Out:
#         pclass  survived        age     sibsp     parch        fare
# deck
# ?     2.617357  0.302761  27.406654  0.503945  0.367850   19.132707
# A     1.000000  0.500000  44.157895  0.181818  0.181818   41.244314
# B     1.000000  0.723077  36.476190  0.446154  0.661538  122.383078
# C     1.000000  0.606383  38.382752  0.680851  0.414894  107.926598
# D     1.130435  0.695652  39.702381  0.413043  0.260870   53.007339
# E     1.243902  0.731707  38.118421  0.341463  0.390244   54.564634
# F     2.380952  0.619048  21.333333  0.428571  0.523810   18.079367
# G     3.000000  0.600000  12.000000  0.600000  1.200000   14.205000
# T     1.000000  0.000000  45.000000  0.000000  0.000000   35.500000

# %%
titanic.groupby("deck")["survived"].mean().sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='deck'>

# %%
s=pd.Series(["  dipen        ", "thapa.   ", "diversant\n","   converging\t"])

# %%
s
# Out:
# 0      dipen
# 1          thapa.
# 2        diversant\n
# 3       converging\t
# dtype: object

# %%
s.str.strip()[3]  #strip removes any leading or trailing space, newline or tab
# Out:
# 'converging'

# %%
s[3]
# Out:
# '   converging\t'

# %%
s.str.strip()
# Out:
# 0         dipen
# 1        thapa.
# 2     diversant
# 3    converging
# dtype: object

# %%
"  dipen\t".strip()
# Out:
# 'dipen'

# %%
s.str.strip(to_strip="tdc \n\t")
# Out:
# 0         ipen
# 1        hapa.
# 2      iversan
# 3    onverging
# dtype: object

# %%
"  di".strip()
# Out:
# 'di'

# %%
"  di ".rstrip()#rstrip is trailing strip/right strip
# Out:
# '  di'

# %%
"  di ".lstrip()#lstrip is leading strip/left strip
# Out:
# 'di '

# %%
s.str.lstrip(to_strip=" dn")[0]
# Out:
# 'ipen        '

# %%
s.str.rstrip(to_strip=" dn")[0]
# Out:
# '  dipe'

# %%
s.str.rstrip(to_strip=" dn")
# Out:
# 0               dipe
# 1             thapa.
# 2        diversant\n
# 3       converging\t
# dtype: object

# %%
"dip-en".split("-")
# Out:
# ['dip', 'en']

# %%
"dip en".split(" ")
# Out:
# ['dip', 'en']

# %%
"-".join(['dip', 'en'])
# Out:
# 'dip-en'

# %%
titanic["home.dest"].str.split("/") #bydefault split on space char
# Out:
# 0                           [St Louis, MO]
# 1       [Montreal, PQ ,  Chesterville, ON]
# 2       [Montreal, PQ ,  Chesterville, ON]
# 3       [Montreal, PQ ,  Chesterville, ON]
# 4       [Montreal, PQ ,  Chesterville, ON]
#                        ...
# 1304                                   [?]
# 1305                                   [?]
# 1306                                   [?]
# 1307                                   [?]
# 1308                                   [?]
# Name: home.dest, Length: 1309, dtype: object

# %%
titanic["home.dest"].str.split("/", expand=True)
# Out:
#                   0                  1     2
# 0      St Louis, MO               None  None
# 1     Montreal, PQ    Chesterville, ON  None
# 2     Montreal, PQ    Chesterville, ON  None
# 3     Montreal, PQ    Chesterville, ON  None
# 4     Montreal, PQ    Chesterville, ON  None
# ...             ...                ...   ...
# 1304              ?               None  None
# 1305              ?               None  None
# 1306              ?               None  None
# 1307              ?               None  None
# 1308              ?               None  None
#
# [1309 rows x 3 columns]

# %%
titanic["home.dest"]
# Out:
# 0                          St Louis, MO
# 1       Montreal, PQ / Chesterville, ON
# 2       Montreal, PQ / Chesterville, ON
# 3       Montreal, PQ / Chesterville, ON
# 4       Montreal, PQ / Chesterville, ON
#                      ...
# 1304                                  ?
# 1305                                  ?
# 1306                                  ?
# 1307                                  ?
# 1308                                  ?
# Name: home.dest, Length: 1309, dtype: object

# %%
titanic["home"]=titanic["home.dest"].str.split("/", expand=True)[0]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["destination"]=titanic["home.dest"].str.split("/", expand=True)[1]

# %%
titanic
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
titanic["home"].value_counts()
# Out:
# ?                                564
# New York, NY                      64
# Cornwall                          19
# London                            14
# London                            13
#                                 ...
# Chelsea, London                    1
# Harrow-on-the-Hill, Middlesex      1
# Copenhagen, Denmark                1
# Frankfort, KY                      1
# Antwerp, Belgium                   1
# Name: home, Length: 339, dtype: int64

# %%
titanic["destination"].value_counts()
# Out:
#  Akron, OH          11
#  Montreal, PQ        9
#  New York, NY        9
#  Detroit, MI         6
#  Cooperstown, NY     5
#                     ..
#  Rochester, NY       1
#   New York, NY       1
#  Pennsylvania        1
#  Toledo, OH          1
#  Stanton, OH         1
# Name: destination, Length: 77, dtype: int64

# %%
titanic["home.dest"].str.split("/", expand=True, n=1)# n=1 means split only one time. can also use regx rather than /.
# Out:
#                   0                  1
# 0      St Louis, MO               None
# 1     Montreal, PQ    Chesterville, ON
# 2     Montreal, PQ    Chesterville, ON
# 3     Montreal, PQ    Chesterville, ON
# 4     Montreal, PQ    Chesterville, ON
# ...             ...                ...
# 1304              ?               None
# 1305              ?               None
# 1306              ?               None
# 1307              ?               None
# 1308              ?               None
#
# [1309 rows x 2 columns]

# %%
a=titanic["home.dest"]

# %%
a.str.rsplit("/", expand=True, n=1)
# Out:
#                   0                  1
# 0      St Louis, MO               None
# 1     Montreal, PQ    Chesterville, ON
# 2     Montreal, PQ    Chesterville, ON
# 3     Montreal, PQ    Chesterville, ON
# 4     Montreal, PQ    Chesterville, ON
# ...             ...                ...
# 1304              ?               None
# 1305              ?               None
# 1306              ?               None
# 1307              ?               None
# 1308              ?               None
#
# [1309 rows x 2 columns]

# %%
#there is also right split rsplit(), by default split start from left so you can use rsplit if you want to start it from right we dont use it none of the time

# %%
titanic.cabin.replace("?","???")#it replace all text(?) in this case or not. there is also python replace .str.replace() replaces part of string not entire text.
# Out:
# 0            B5
# 1       C22 C26
# 2       C22 C26
# 3       C22 C26
# 4       C22 C26
#          ...
# 1304        ???
# 1305        ???
# 1306        ???
# 1307        ???
# 1308        ???
# Name: cabin, Length: 1309, dtype: object

# %%
"diopcghvhv".replace("di","hi")
# Out:
# 'hiopcghvhv'

# %%
ufos=pd.read_csv("data/nuforc_reports.csv")

# %%
ufos
# Out:
#                                                  summary            city  \
# 0      My wife was driving southeast on a fairly popu...         Chester
# 1      I think that I may caught a UFO on the NBC Nig...      Rocky Hill
# 2      I woke up late in the afternoon 3:30-4pm. I we...             NaN
# 3      I was driving towards the intersection of fall...          Ottawa
# 4      In Peoria Arizona, I saw a cigar shaped craft ...          Peoria
# ...                                                  ...             ...
# 88120  4 lights in formation over Tempe appear while ...           Tempe
# 88121  2 bright star like lights in the NNW skys,  ((...         Bolivar
# 88122  I just witnessed a ‘Phoenix Lights’ type of fo...      North Port
# 88123  Witnessed an orange, slow moving light. Was lo...  Black Mountain
# 88124  Glowing lights in formation  just south of San...    Marin County
#
#       state            date_time      shape     duration  \
# ...

# %%
u=ufos["duration"]

# %%
u.str.replace("minutes|seconds", lambda a:a.group[0], regex=True )
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 88120    NaN
# 88121    NaN
# 88122    NaN
# 88123    NaN
# 88124    NaN
# Name: duration, Length: 88125, dtype: object

# %%
def abbrv(reo):
#     print(reo)
    return reo.group()[0]
# reo=regular expression object

# %%
ufos["duration"].str.replace("minutes|seconds|hours", abbrv, regex=True)
# Out:
# 0          5 s
# 1        3-5 s
# 2          NaN
# 3         10 s
# 4          2 m
#          ...
# 88120      3 m
# 88121     20 s
# 88122     20 s
# 88123      2 m
# 88124      3 m
# Name: duration, Length: 88125, dtype: object

# %%
ufos["duration"].str.contains("days", na=False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 88120    False
# 88121    False
# 88122    False
# 88123    False
# 88124    False
# Name: duration, Length: 88125, dtype: bool

# %%
a=ufos["duration"]

# %%
ufos[a.str.contains("hours|month|days", na=False, regex=True)]
# Out:
#                                                  summary           city state  \
# 36     Looked like airplanes without windows,  wings,...      Morehouse    MO
# 37     01/20/51     Palm Springs CA     light     hou...   Palm Springs    CA
# 40     5/16/1958/ 1500 hours/ just getting dark,mount...     Cincinnati    OH
# 99                              Missing Time: Two People  Mount Weather    VA
# 107    7 large yellow lights with red center  estimat...        Griffin    GA
# ...                                                  ...            ...   ...
# 87833       Bright light fluidly moving through the sky.        Castaic    CA
# 87890  Bright white light was stationary, turned to O...     Interlaken    NY
# 87976  Bright, red,white&green flying objects near re...        Reading    PA
# 88064  Unidentified object moving very slowly across ...  Pt. St. Lucie    FL
# 88065              White circular object above Ft Pierce    Fort Pierce    FL
#
# ...

# %%
ufos[ufos["duration"].str.contains("day|week|month|year", na=False)]
# Out:
#                                                  summary  \
# 107    7 large yellow lights with red center  estimat...
# 116    Saw one large ship during the day around noon ...
# 286    film makers in hollywood where talking of film...
# 290                               End of the Century UFO
# 1355   A white ball of light made several appearances...
# ...                                                  ...
# 84983  In 1967 I am a little kid now. I am sleeping I...
# 85717  There was a big bright colored triangle object...
# 86210  2 flying diamonds; red and gold lights; creaki...
# 87146                         My life being being taken.
# 87707  Lights seen from the night sky 1st night-flick...
#
#                           city state            date_time      shape  \
# 107                    Griffin    GA  1984-03-15T20:00:00     circle
# 116                  Knoxville    TN  1986-04-04T23:00:00  rectangle
# 286                    Arizona    AZ  1997-07-07T00:00:00   triangle
# ...
